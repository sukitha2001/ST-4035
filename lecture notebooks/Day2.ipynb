# %% [markdown]
# ### Problem Definision
# Predicting Whether patterns in Sri Lanka based on historical wheather data.
#
# ### Data Collection
# Collect data from kaggle dataset.\
# Request data from meteorological department Sri Lanka.
#
# ### Data Wrangling
# Removing or Impute missing values\
# Identifying Outliars\
# Data Scaling
#
# ### EDA
# Ploting Time Series Plots\
# PACF Plots
#
# ### Model Building and Training
# Fitting a SARIMA model\
# Using a LSTM Deeplearning Model
#
# ### Model Evaluation and Tuning
# Hyperparameter Tuning and Calculating RMSE
#
# ### Deployment and Monitoring
# Deploying the model on Google Cloud
#
# ### Comunicating the Insights
# Deploying a Streamlit Dashboard.

# %% [markdown]
# RMSE = sqrt(sum(Y-Y_hat)^2/n)
#
# If there is multicoliniarity we use regularization
